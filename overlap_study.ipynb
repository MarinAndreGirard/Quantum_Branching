# %%
import numpy as np
import qutip as qt
import math
import matplotlib.pyplot as plt
from q_solve import generate_result
from Schmidt_solve import compute_schmidt_states
from VN import plot_VN
from VN import compute_VN_time
from e_spectrum import plot_e_spectrum
from Neff import plot_Neff_schmidt_Neff_tot
from checkup import checkup
from overlap import plot_p_overlap_graph
from overlap import plot_p_overlap_graph_characterize
from Interference import total_interference

# %%
plot_p_overlap_graph_characterize()
# Out:
# wi_0.1_EI_0.03
# generated
# wi_0.1_EI_0.05
# generated
# wi_0.1_EI_0.07
# generated
# wi_0.1_EI_0.09
# generated
# wi_0.2_EI_0.03
# generated
# wi_0.2_EI_0.05
# generated
# wi_0.2_EI_0.07
# generated
# wi_0.2_EI_0.09
# generated
# wi_0.3_EI_0.03
# generated
# wi_0.3_EI_0.05
# generated
# wi_0.3_EI_0.07
# generated
# wi_0.3_EI_0.09
# generated
# wi_0.4_EI_0.03
# generated
# wi_0.4_EI_0.05
# generated
# wi_0.4_EI_0.07
# generated
# wi_0.4_EI_0.09
# generated

# %%
checkup()
# Out:
# /Users/maringirard/Dev/Quantum_Branching/VN.py:8: RuntimeWarning: divide by zero encountered in log2
#   entropy = -np.sum(np.nan_to_num(np.log2(np.linalg.eigvals(density_matrix.full())) * np.linalg.eigvals(density_matrix.full())))
# /Users/maringirard/Dev/Quantum_Branching/VN.py:8: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(np.nan_to_num(np.log2(np.linalg.eigvals(density_matrix.full())) * np.linalg.eigvals(density_matrix.full())))
# /Users/maringirard/Dev/Quantum_Branching/Quantum_Branching/lib/python3.11/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/maringirard/Dev/Quantum_Branching/Quantum_Branching/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#defining all quantities used in the simulation
d1, d2 = 10, 200
w = 0.3# smallest weight of the 2 eingestates, set btw 0 and 1
E_spacing = 1.0
Int_strength = 0.0311
# Define the time settings for the simulation
tmax= 10
ind_nb = 100
result, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_total, ket_0, ket_1, initial_state_system_2 = generate_result(d1,d2,w, E_spacing, Int_strength, tmax, ind_nb,0)
eigenenergies_total, eigenstates_total = H_total.eigenstates()

# %%
plot_p_overlap_graph(tlist,result,H_total,w,Int_strength,log_scale=False)
plot_VN(result,tlist,0)
total_interference(tlist,result,eigenstates_total,eigenenergies_total,Int_strength,w)
# Out:
# /Users/maringirard/Dev/Quantum_Branching/VN.py:8: RuntimeWarning: divide by zero encountered in log2
#   entropy = -np.sum(np.nan_to_num(np.log2(np.linalg.eigvals(density_matrix.full())) * np.linalg.eigvals(density_matrix.full())))
# /Users/maringirard/Dev/Quantum_Branching/VN.py:8: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(np.nan_to_num(np.log2(np.linalg.eigvals(density_matrix.full())) * np.linalg.eigvals(density_matrix.full())))
# /Users/maringirard/Dev/Quantum_Branching/Quantum_Branching/lib/python3.11/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/maringirard/Dev/Quantum_Branching/Quantum_Branching/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#defining all quantities used in the simulation
d1, d2 = 10, 200
w = 0.5# smallest weight of the 2 eingestates, set btw 0 and 1
E_spacing = 1.0
Int_strength = 0.03
# Define the time settings for the simulation
tmax= 10
ind_nb = 100
result, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_total, ket_0, ket_1, initial_state_system_2 = generate_result(d1,d2,w, E_spacing, Int_strength, tmax, ind_nb,1)
eigenenergies_total, eigenstates_total = H_total.eigenstates() 

plot_p_overlap_graph(tlist,result,H_total,w,Int_strength,log_scale=True)

# %% [markdown]
# For w=0.5 the overlap increases, but I dont think we have to worry about it.

# %%
resulta2, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala2, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,0.4, E_spacing, 0.06, 1000,1000,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 resulta2, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala2, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,0.4, E_spacing, 0.06, 1000,1000,1)
# ----> 3 plot_p_overlap_graph(tlist,resulta2,H_totala2,0.4,EI,True)
#
# NameError: name 'EI' is not defined

# %%
plot_p_overlap_graph(tlist,resulta2,H_totala2,0.4,Int_strength,True)

# %%
resulta3, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala3, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,0.3, E_spacing, 0.06, 100,100,1)
plot_p_overlap_graph(tlist,resulta3,H_totala3,0.3,Int_strength,True)

# %%
#Testing the overlap plot on different w
#we make them run for a bit longer as well
w=0.3

# %%
EI=0.01
resulta1, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala1, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 1000,100,1)
plot_p_overlap_graph(tlist,resulta1,H_totala1,w,EI,True)

# %%
EI=0.03
resulta2, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala2, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 100,1000,0)
plot_p_overlap_graph(tlist,resulta2,H_totala2,w,EI,False)

# %%
EI=0.06
resulta3, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala3, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 1000,100,1)
plot_p_overlap_graph(tlist,resulta3,H_totala3,w,EI,True)

# %%
EI=0.09
resulta4, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala4, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 1000,100,1)
plot_p_overlap_graph(tlist,resulta4,H_totala4,w,EI,True)

# %%
EI=0.12
resulta5, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala5, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 1000,100,1)
plot_p_overlap_graph(tlist,resulta5,H_totala5,w,EI,True)

# %%
EI=0.15
resulta6, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala6, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 1000,1000,1)
plot_p_overlap_graph(tlist,resulta6,H_totala6,w,EI,True)

# %%
EI=0.2
resulta7, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala7, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 1000,1000,1)
plot_p_overlap_graph(tlist,resulta7,H_totala7,w,EI,True)

# %%
EI=0.25
resulta8, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala8, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 1000,1000,1)
plot_p_overlap_graph(tlist,resulta8,H_totala8,w,EI,True)
# Out:
# /Users/maringirard/Dev/Quantum_Branching/Quantum_Branching/lib/python3.11/site-packages/scipy/integrate/_ode.py:431: UserWarning: zvode: Excess work done on this call. (Perhaps wrong MF.)
#   self._y, self.t = mth(self.f, self.jac or (lambda: None),
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 EI=0.25
# ----> 2 resulta8, tlist, H_q, H_system_2, H_system_1_ext, H_system_2_ext, H_interaction, H_totala8, ket_0, ket_1, initial_state_system_2 = generate_result(10,200,w, E_spacing, EI, 1000,1000,1)
#       3 plot_p_overlap_graph(tlist,resulta8,H_totala8,w,EI)
#
# File ~/Dev/Quantum_Branching/q_solve.py:64, in generate_result(d1, d2, w, E_spacing, Int_strength, tmax, ind_nb, log)
#      61     raise ValueError("Invalid value for 'log'. It should be either 0 or 1.")
#      63 # Perform time evolution of the combined system
# ...
